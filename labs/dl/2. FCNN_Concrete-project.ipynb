# %%
# !pip install tensorflow
# pandas openpyxl scikit-learn seaborn keras tensorflow

# %%
import pandas as pd
HDNames = ['Cement','BFS','FLA','Water','SP','CA','FA','Age','CCS']

# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks

# %%
Data = pd.read_excel('1. ConcreteData.xlsx', names=HDNames)

# %%
Data.head(20)
# Out:
#     Cement    BFS  FLA  Water   SP      CA     FA  Age        CCS
# 0    540.0    0.0  0.0  162.0  2.5  1055.0  676.0   28  61.887366
# 1    332.5  142.5  0.0  228.0  0.0   932.0  594.0  270  40.269535
# 2    332.5  142.5  0.0  228.0  0.0   932.0  594.0  365  41.052780
# 3    198.6  132.4  0.0  192.0  0.0   978.4  825.5  360  44.296075
# 4    266.0  114.0  0.0  228.0  0.0   932.0  670.0   90  47.029847
# 5    380.0   95.0  0.0  228.0  0.0   932.0  594.0  365  43.698299
# 6    380.0   95.0  0.0  228.0  0.0   932.0  594.0   28  36.447770
# 7    266.0  114.0  0.0  228.0  0.0   932.0  670.0   28  45.854291
# 8    475.0    0.0  0.0  228.0  0.0   932.0  594.0   28  39.289790
# 9    198.6  132.4  0.0  192.0  0.0   978.4  825.5   90  38.074244
# 10   198.6  132.4  0.0  192.0  0.0   978.4  825.5   28  28.021684
# 11   427.5   47.5  0.0  228.0  0.0   932.0  594.0  270  43.012960
# 12   190.0  190.0  0.0  228.0  0.0   932.0  670.0   90  42.326932
# 13   304.0   76.0  0.0  228.0  0.0   932.0  670.0   28  47.813782
# 14   380.0    0.0  0.0  228.0  0.0   932.0  670.0   90  52.908320
# 15   139.6  209.4  0.0  192.0  0.0  1047.0  806.9   90  39.358048
# 16   342.0   38.0  0.0  228.0  0.0   932.0  670.0  365  56.141962
# 17   380.0   95.0  0.0  228.0  0.0   932.0  594.0   90  40.563252
# 18   475.0    0.0  0.0  228.0  0.0   932.0  594.0  180  42.620648
# 19   427.5   47.5  0.0  228.0  0.0   932.0  594.0  180  41.836714

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cement  1029 non-null   float64
#  1   BFS     1029 non-null   float64
#  2   FLA     1029 non-null   float64
#  3   Water   1029 non-null   float64
#  4   SP      1029 non-null   float64
#  5   CA      1029 non-null   float64
#  6   FA      1029 non-null   float64
#  7   Age     1029 non-null   int64
#  8   CCS     1029 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
summary = Data.describe()
print(summary)
# Out:
#             Cement          BFS          FLA        Water           SP  \
# count  1029.000000  1029.000000  1029.000000  1029.000000  1029.000000
# mean    280.914091    73.967298    54.239796   181.585374     6.206710
# std     104.245542    86.290255    64.005258    21.357226     5.975279
# min     102.000000     0.000000     0.000000   121.750000     0.000000
# 25%     192.000000     0.000000     0.000000   164.900000     0.000000
# 50%     272.800000    22.000000     0.000000   185.000000     6.350000
# 75%     350.000000   143.000000   118.270000   192.000000    10.160000
# max     540.000000   359.400000   200.100000   247.000000    32.200000
#
#                 CA           FA          Age          CCS
# count  1029.000000  1029.000000  1029.000000  1029.000000
# mean    972.853401   773.673712    45.679300    35.774912
# std      77.763459    80.156602    63.198226    16.656880
# min     801.000000   594.000000     1.000000     2.331808
# 25%     932.000000   732.600000     7.000000    23.696601
# 50%     968.000000   779.700000    28.000000    34.397958
# 75%    1029.400000   824.000000    56.000000    45.939786
# max    1145.000000   992.600000   365.000000    82.599225

# %%
# boxplot is a graphical representation used to describe the distribution of a sample by simple dispersion and position indexes

# %%
import seaborn as sns
sns.set(style="ticks") # color of the axes. The available styles are darkgrid, white grid, dark, white, and ticks
sns.boxplot(data=Data)
# Out:
# <Axes: >

# %%
sns.pairplot(data=Data)

# %% [markdown]
# Focusing on the last line of the graph, it contains scatter plots of the target of our concrete compressive strength (CCS) data compared to the predictors. Except foer Cement, there is no particular trend.

# %% [markdown]
# x(scaled) = (x-x(min)/(x(max)-x(min)))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
print(scaler.fit(Data))
# Out:
# MinMaxScaler()

# %%
DataScaled= scaler.fit_transform(Data)
DataScaled= pd.DataFrame(DataScaled, columns=HDNames)

# %%
summary = DataScaled.describe()
print(summary)
# Out:
#             Cement          BFS          FLA        Water           SP  \
# count  1029.000000  1029.000000  1029.000000  1029.000000  1029.000000
# mean      0.408480     0.205808     0.271063     0.477728     0.192755
# std       0.238004     0.240095     0.319866     0.170517     0.185568
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.205479     0.000000     0.000000     0.344511     0.000000
# 50%       0.389954     0.061213     0.000000     0.504990     0.197205
# 75%       0.566210     0.397885     0.591054     0.560878     0.315528
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 CA           FA          Age          CCS
# count  1029.000000  1029.000000  1029.000000  1029.000000
# mean      0.499574     0.450762     0.122745     0.416646
# std       0.226057     0.201095     0.173621     0.207517
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.380814     0.347717     0.016484     0.266170
# 50%       0.485465     0.465881     0.074176     0.399491
# 75%       0.663953     0.577020     0.151099     0.543284
# max       1.000000     1.000000     1.000000     1.000000

# %%
sns.boxplot(data=DataScaled)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
Predictors = pd.DataFrame(DataScaled.iloc[:,:8])
Response = pd.DataFrame(DataScaled.iloc[:,8])

# %%
Pred_train, Pred_test, Resp_train, Resp_test =train_test_split(Predictors, Response,test_size = 0.2, random_state=1 ) #30% of the data is divided up as test data

print(Pred_train.shape)
print(Pred_test.shape)
print(Resp_train.shape)
print(Resp_test.shape)
# Out:
# (823, 8)
# (206, 8)
# (823, 1)
# (206, 1)

# %% [markdown]
# 1.   Import the Sequential from keras.models
#
# 1.   Stack layers using the .add() method
# 2.   Configure the learning process using .compile() method
# 2.   Train the model on train dataset using .fit() method

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, BatchNormalization, Dropout, Input
from keras.optimizers import Adam, SGD, RMSprop     

# fully connected neural network with 4 levels (2 hidden layers)
model = Sequential()

model.add(Input(input_dim=8))# , input_dim=8, input_shape=(8,) 
model.add(Dense(20, activation='relu'))# , input_dim=8, input_shape=(8,) 
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 511 (2.00 KB)
#  Trainable params: 511 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 1.   adam optimizer: This is an algorithm for first order, gradient-based optimization of stochastic objective function based on adaptive estimates of lower order moments
# 2.   mean_squared_error loss function: Mean squared error (MSE) measures the average of the squares errors- tahat is the average squared difference between the actual estimaed values and what's to be estimated. MSE is a measure of the quality of an estimator- it's always non-negative and the coloser the values are to zero, the better
#
#
# 1.   accuracy metric: A metric is a function that is used to evaluate the performance of your model during training and testing

# %%
history = model.fit(Pred_train, Resp_train, epochs=100, verbose=1, validation_split=0.2, batch_size=128)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.3630e-04 - loss: 0.0499
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 9.0005e-05 - loss: 0.0286
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0014 - loss: 0.0230
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 4.0044e-04 - loss: 0.0210
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0019 - loss: 0.0198
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 5.2566e-04 - loss: 0.0189
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0012 - loss: 0.0176
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0019 - loss: 0.0159
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 6.6608e-04 - loss: 0.0152
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 7.4324e-04 - loss: 0.0140
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0014 - loss: 0.0141
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0012 - loss: 0.0135
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.3630e-04 - loss: 0.0117
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.3630e-04 - loss: 0.0112
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0024 - loss: 0.0118
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 9.1494e-04 - loss: 0.0102
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0024 - loss: 0.0102
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 9.1494e-04 - loss: 0.0102
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 5.2566e-04 - loss: 0.0088
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 3.4257e-04 - loss: 0.0087
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.8746e-04 - loss: 0.0090
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0017 - loss: 0.0088
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.3630e-04 - loss: 0.0088
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 4.0044e-04 - loss: 0.0085
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0011 - loss: 0.0081
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0024 - loss: 0.0078
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.8746e-04 - loss: 0.0071
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0011 - loss: 0.0077
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0019 - loss: 0.0074
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 2.8746e-04 - loss: 0.0069
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0012 - loss: 0.0070
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 2.3485e-04 - loss: 0.0067
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0028 - loss: 0.0066
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 9.0005e-05 - loss: 0.0068
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.8453e-04 - loss: 0.0065
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0011 - loss: 0.0063
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0021 - loss: 0.0060
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0028 - loss: 0.0063
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0019 - loss: 0.0057
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 5.2566e-04 - loss: 0.0057
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 2.3485e-04 - loss: 0.0064
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy:
100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0011 - loss: 0.0041

# %% [markdown]
# *   Pred_train: This is an array of predictors training data
# *   Resp_train: This is an array of response data
#
#
# *   epochs = 1000: This is the number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
# *   verbose = 1: this is an integer: 0,1,and 2. Here the different verbosity modes represent the following; 0 = silent, 1 = progress bar and 2 = one line per epoch

# %% [markdown]
# Calculate the coefficient of determination (R-squared)
#
# *   R-squared is a meausre of how well a model can predict the data, and it lies between 0 and 1; The higher the value of the coefficient of determination, the better the mode is at predicting the data.
# *   R-squared (also denoted as R2) is defined as the proportion of variances in the depedent variable that is predictable from the independent variable.
# To calcalate the coefficient of determination we can use the r2_score() function

# %%
from sklearn.metrics import r2_score
# to calcualte R2 we need ground truth target values and the estimated target values
y_predKM = model.predict(Pred_test)
print('Coefficient of determination of Keras Model')
print(r2_score(Resp_test,y_predKM))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Coefficient of determination of Keras Model
# 0.8432396650314331

# %% [markdown]
# Outlier distort data analysis result
#
# ---
# We will use Turkey's method which will use the interquartile range (IQR) approach
#
#
# ---
#
# IQR  = DataScaled.quantile(0.75) - DataScaled.quantile(0.25)

# %%
Q1 = DataScaled.quantile(0.25)
Q3= DataScaled.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Cement    0.360731
# BFS       0.397885
# FLA       0.591054
# Water     0.216367
# SP        0.315528
# CA        0.283140
# FA        0.229303
# Age       0.134615
# CCS       0.277114
# dtype: float64

# %%
DataScaledOut = DataScaled[~((DataScaled < (Q1 - 1.5 * IQR)) | (DataScaled > (Q3 + 1.5 * IQR))).any(axis=1)]
DataScaledOut.shape
#1029 to 925
# Out:
# (925, 9)

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.subplot(121)
sns.boxplot(data = DataScaled)
plt.title("Data with outliers")

plt.subplot(122)
sns.boxplot(data = DataScaledOut)
# Out:
# <Axes: >

# %%
#mahmoudramadan155/ML
#01144232656

# %%
Predictors2 = pd.DataFrame(DataScaledOut.iloc[:,:8])
Response2  =pd.DataFrame(DataScaledOut.iloc[:,8])

# %%
Pred_train2,Pred_test2,Resp_train2,Resp_test2=train_test_split(Predictors2, Response2,test_size = 0.2, random_state=1) #30% of the data is divided up as test data
print(Pred_train2.shape)
print(Pred_test2.shape)
print(Resp_train2.shape)
print(Resp_test2.shape)
# Out:
# (740, 8)
# (185, 8)
# (740, 1)
# (185, 1)

# %%
# fully connected neural network with 4 levels (2 hidden layers)
model = Sequential()
model.add(Dense(20, input_shape=(8,), activation='relu')) # input layer which has 20 neurons, 8 input colums
model.add(Dense(10, activation='relu'))# second layer which has 10 neurons
model.add(Dense(10, activation='relu'))# third layers which has 10 neurons
model.add(Dense(1, activation='linear')) # output layer which has 1 neuron

# %%
model.compile(optimizer='adam',loss='mean_sqbiuared_error', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None,
100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 4.0044e-04 - loss: 0.0077
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 7.4324e-04 - loss: 0.0074
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0015 - loss: 0.0075
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0019 - loss: 0.0076
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0033 - loss: 0.0077
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0014 - loss: 0.0077
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.3630e-04 - loss: 0.0071
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0024 - loss: 0.0069
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0011 - loss: 0.0076
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 7.4324e-04 - loss: 0.0076
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0024 - loss: 0.0082
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0028 - loss: 0.0080
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 7.4324e-04 - loss: 0.0076
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 5.9374e-04 - loss: 0.0079
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0028 - loss: 0.0065
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 7.4324e-04 - loss: 0.0070
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0017 - loss: 0.0075
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 7.4324e-04 - loss: 0.0069
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0045 - loss: 0.0072
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0014 - loss: 0.0073
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0024 - loss: 0.0074
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0017 - loss: 0.0070
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 8.2591e-04 - loss: 0.0069
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.8746e-04 - loss: 0.0066
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 5.2566e-04 - loss: 0.0070
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 4.6136e-04 - loss: 0.0077
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.8453e-04 - loss: 0.0065
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 2.3485e-04 - loss: 0.0064
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0012 - loss: 0.0070
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 6.6608e-04 - loss: 0.0068
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0017 - loss: 0.0074
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 2.8746e-04 - loss: 0.0067
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0024 - loss: 0.0073
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 3.4257e-04 - loss: 0.0067
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.8453e-04 - loss: 0.0069
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 9.1494e-04 - loss: 0.0071
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0019 - loss: 0.0060
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 5.9374e-04 - loss: 0.0072
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0033 - loss: 0.0063
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 4.6136e-04 - loss: 0.0055
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0017 - loss: 0.0067
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 2.3485e-04 - loss: 0.0062
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 3.4257e-04 - loss: 0.0060
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.8453e-04 - loss: 0.0060
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 5.9374e-04 - loss: 0.0061

# %%
Y_predKM2 = model.predict(Pred_test2)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
print('Coefficient of determination if Neural Network Model without outliers')
print(r2_score(Resp_test2,Y_predKM2))
# Out:
# Coefficient of determination if Neural Network Model without outliers
# 0.8511314392089844

# %%
plt.figure(1)
plt.subplot(121)
plt.scatter(Resp_test,y_predKM)
plt.plot([0,1],[0,1],linewidth=2)
plt.title("Data with outliers")
# Out:
# Text(0.5, 1.0, 'Data with outliers')

# %%
plt.subplot(122)
plt.scatter(Resp_test2,Y_predKM2)
plt.plot([0,1],[0,1],linewidth=2)
plt.title("Data without outliers")
# Out:
# Text(0.5, 1.0, 'Data without outliers')
